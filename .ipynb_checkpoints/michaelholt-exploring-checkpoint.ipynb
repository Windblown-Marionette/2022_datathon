# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Importing DataFrames

# %%
care_df = pd.read_csv('data/care_management_anonymized.csv')

# %%
care_df.head(10)
# Out:
#    anon_ID      assistance_date                        assistance_category  \
# 0      531  2019-01-01 12:50:00  Remote Contact with client (phone, email)
# 1      531  2019-01-02 07:30:00  Remote Contact with client (phone, email)
# 2      581  2019-01-02 09:50:00  Remote Contact with client (phone, email)
# 3      337  2019-01-02 10:10:00  Remote Contact with client (phone, email)
# 4      254  2019-01-02 10:15:00  Remote Contact with client (phone, email)
# 5      415  2019-01-02 10:15:00  Remote Contact with client (phone, email)
# 6       72  2019-01-02 10:20:00  Remote Contact with client (phone, email)
# 7      533  2019-01-02 10:25:00                            ElderNet Office
# 8      592  2019-01-02 10:40:00  Remote Contact with client (phone, email)
# 9      592  2019-01-02 10:45:00  Remote Contact with client (phone, email)
#
#    amount     unit CommType Party InitiatedBy Benefit_1 Assistance_1  \
# 0     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 1     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 2    14.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 3     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 4     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 5     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 6     3.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 7     5.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 8     8.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 9     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
#
#   Benefit_2 Assistance_2 Benefit_3 Assistance_3
# 0       NaN          NaN       NaN          NaN
# 1       NaN          NaN       NaN          NaN
# 2       NaN          NaN       NaN          NaN
# 3       NaN          NaN       NaN          NaN
# 4       NaN          NaN       NaN          NaN
# 5       NaN          NaN       NaN          NaN
# 6       NaN          NaN       NaN          NaN
# 7       NaN          NaN       NaN          NaN
# 8       NaN          NaN       NaN          NaN
# 9       NaN          NaN       NaN          NaN

# %%
care_df[care_df['Party'].notna()]['Party'].value_counts()
# Out:
# Client              3272
# Service Provider     619
# Family               279
# ElderNet             232
# Other                126
# Social Worker         84
# Friend                41
# Care Manager          12
# Eldernet               7
# Care Coordinator       2
# Clinet                 1
# Name: Party, dtype: int64

# %%
care_df.value_counts()
# Out:
# anon_ID  assistance_date      assistance_category                        amount  unit     CommType   Party   InitiatedBy  Benefit_1       Assistance_1  Benefit_2  Assistance_2  Benefit_3          Assistance_3
# 8        2020-05-06 15:45:00  Remote Contact with client (phone, email)  24.0    Minutes  Call       Client  ElderNet     Food            Enrollment    Medical    Information   ADL                Support         1
# 343      2020-05-13 10:40:00  Remote Contact with client (phone, email)  23.0    Minutes  Call       Client  ElderNet     Transportation  Coordination  Housing    Coordination  Telecommunication  Information     1
# 512      2021-01-20 13:45:00  Remote Contact with client (phone, email)  43.0    Minutes  Call       Client  ElderNet     Financial       Information   Food       Information   Pets               Enrollment      1
#          2021-01-20 09:40:00  Remote Contact with client (phone, email)  32.0    Minutes  Call       Client  Other Party  Financial       Information   Medical    Information   ElderNet           Support         1
# 457      2021-03-01 12:15:00  Remote Contact with client (phone, email)  5.0     Minutes  Call       Client  Other Party  ADL             Coordination  Medical    Coordination  Financial          Coordination    1
#                                                                                                                                                                                                                    ..
# 245      2021-01-22 10:50:00  Remote Contact with client (phone, email)  19.0    Minutes  Call       Client  ElderNet     Financial       Information   Housing    Referral      ElderNet           Support         1
# 242      2021-08-26 14:00:00  Remote Contact with client (phone, email)  14.0    Minutes  Call       Family  ElderNet     Housing         Information   Medical    Information   Financial          Information     1
# 234      2020-09-29 15:40:00  Community                                  15.0    Minutes  In Person  Client  Other Party  ElderNet        Information   Food       Information   Pets               Support         1
#          2020-09-17 14:50:00  Remote Contact with client (phone, email)  1.0     Minutes  In Person  Client  Other Party  ElderNet        Information   Food       Information   Pets               Support         1
# 634      2021-01-22 12:30:00  Remote Contact with client (phone, email)  16.0    Minutes  Call       Client  ElderNet     Financial       Enrollment    Medical    Information   ElderNet           Support         1
# Length: 81, dtype: int64

# %%
client_df = pd.read_csv('data/client_info_anonymized.csv')

# %%
client_df.head(10)
# Out:
#    anon_ID      county poverty minority age_group
# 0        1  Montgomery      No      NaN         P
# 1        2  Montgomery      No       No         D
# 2        3  Montgomery      No       No         P
# 3        5  Montgomery      No      NaN         G
# 4        6  Montgomery     Yes      NaN       NaN
# 5        7  Montgomery      No       No         P
# 6        8  Montgomery     Yes      Yes         D
# 7       10  Montgomery     Yes      NaN       NaN
# 8       11  Montgomery      No      NaN         T
# 9       12  Montgomery     Yes      NaN         G

# %%
donations_df = pd.read_csv('data/donations_anonymized.csv')

# %%
donations_df.head(10)
# Out:
#    anon_donor_id      zip  status  do_not_mail  do_not_call organisation  \
# 0             92  19003.0  Active        False        False            N
# 1            321  19096.0  Active        False        False            N
# 2            559  19146.0  Active        False        False            N
# 3            926  19041.0  Active        False        False            N
# 4            860  10038.0  Active        False        False            N
# 5            956  19003.0  Active        False        False            N
# 6            835  19072.0  Active        False        False            N
# 7            119  19041.0  Active        False        False            N
# 8            485  19041.0  Active        False        False            N
# 9            192  19403.0  Active        False        False            N
#
#          date  amount   form    campaign target
# 0  01/01/2019    40.0  Check     Clients   Gift
# 1  01/02/2019    25.0  Check  Fall Towns   Gift
# 2  01/02/2019   250.0  Check  Fall Towns   Gift
# 3  01/03/2019    50.0  Check  Fall Towns   Gift
# 4  01/04/2019   165.0  Check        Misc   Gift
# 5  01/07/2019    32.0  Check  Fall Towns   Gift
# 6  01/07/2019   100.0  Check       Board   Gift
# 7  01/08/2019   100.0  Check       Board   Gift
# 8  01/09/2019    50.0  Check  Fall Towns   Gift
# 9  01/09/2019  1000.0  Check  Corporatio   Gift

# %%
pantry_df = pd.read_csv('data/pantry_anonymized.csv')

# %%
pantry_df.head(10)
# Out:
#    anon_ID assistance_date                assistance_category  amount    unit
# 0      102  1/3/2019 10:00  Food Pantry: Food Pantry Poundage      25  Pounds
# 1      178  1/3/2019 10:00  Food Pantry: Food Pantry Poundage      25  Pounds
# 2      588  1/3/2019 10:30  Food Pantry: Food Pantry Poundage      25  Pounds
# 3      502  1/3/2019 11:15  Food Pantry: Food Pantry Poundage      25  Pounds
# 4      232  1/3/2019 11:30  Food Pantry: Food Pantry Poundage      25  Pounds
# 5      361  1/3/2019 11:40  Food Pantry: Food Pantry Poundage      25  Pounds
# 6      361  1/3/2019 11:40  Food Pantry: Food Pantry Poundage      25  Pounds
# 7      478  1/3/2019 11:55  Food Pantry: Food Pantry Poundage      25  Pounds
# 8      599  1/3/2019 12:45  Food Pantry: Food Pantry Poundage      25  Pounds
# 9      122  1/3/2019 13:00  Food Pantry: Food Pantry Poundage      25  Pounds

# %%
services_df = pd.read_csv('data/volunteer_services_anonymized.csv')

# %%
services_df.head()
# Out:
#    anon_ID rider_first_ride_date rider_last_ride_date  rider_num_rides  \
# 0      276            2015-04-27           2021-11-16                0
# 1      276            2015-04-27           2021-11-16                0
# 2      276            2015-04-27           2021-11-16                0
# 3      276            2015-04-27           2021-11-16                0
# 4      276            2015-04-27           2021-11-16                0
#
#    appt_date  appt_duration     category
# 0  9/15/2021           2.00  Doctor Appt
# 1   9/1/2021           2.00  Doctor Appt
# 2  8/26/2021           2.00  Doctor Appt
# 3  8/11/2021           2.00  Doctor Appt
# 4  8/10/2021           2.25  Doctor Appt

# %% [markdown]
# # Analyses of clients, donors, donations

# %% [markdown]
# ## Clients

# %% [markdown]
# # Analysis of first-time riders

# %%
services_df
# Out:
#       anon_ID rider_first_ride_date rider_last_ride_date  rider_num_rides  \
# 0         276            2015-04-27           2021-11-16                0
# 1         276            2015-04-27           2021-11-16                0
# 2         276            2015-04-27           2021-11-16                0
# 3         276            2015-04-27           2021-11-16                0
# 4         276            2015-04-27           2021-11-16                0
# ...       ...                   ...                  ...              ...
# 4920       81            2015-05-01           2020-02-24                0
# 4921       81            2015-05-01           2020-02-24                0
# 4922       81            2015-05-01           2020-02-24                0
# 4923       81            2015-05-01           2020-02-24                0
# 4924       81            2015-05-01           2020-02-24                0
#
#       appt_date  appt_duration          category
# 0     9/15/2021           2.00       Doctor Appt
# 1      9/1/2021           2.00       Doctor Appt
# 2     8/26/2021           2.00       Doctor Appt
# 3     8/11/2021           2.00       Doctor Appt
# 4     8/10/2021           2.25       Doctor Appt
# ...         ...            ...               ...
# 4920  1/14/2019           2.00  Special Projects
# 4921  1/14/2019           2.00  Special Projects
# 4922  1/14/2019           7.00  Special Projects
# 4923  1/14/2019           3.00  Special Projects
# 4924  1/14/2019           2.00  Special Projects
#
# [4925 rows x 7 columns]

# %% [markdown]
# -----------------------

# %%
services_df.describe()
# Out:
#            anon_ID  rider_num_rides  appt_duration
# count  4925.000000           4925.0    4925.000000
# mean    329.857462              0.0       3.165279
# std     187.983010              0.0       5.648763
# min       2.000000              0.0       0.000000
# 25%     166.000000              0.0       2.000000
# 50%     297.000000              0.0       2.000000
# 75%     505.000000              0.0       3.000000
# max     641.000000              0.0     200.000000

# %% [markdown]
# **rider_num_rides** is all 0's

# %% [markdown]
# ----------------------------------------------

# %% [markdown]
# Getting counts of first-time riders for each day.

# %%
first_ride_daily_counts = pd.DataFrame(services_df['rider_first_ride_date'].value_counts(sort = False))

# %%
date_series = pd.Series(first_ride_daily_counts.index)
date_series = pd.to_datetime(date_series)
date_series
# Out:
# 0     2015-04-27
# 1     2019-01-29
# 2     2019-03-05
# 3     2016-05-31
# 4     2015-05-02
#          ...
# 142   2016-04-15
# 143   2019-01-28
# 144   2018-06-28
# 145   2015-07-08
# 146   2015-05-01
# Length: 147, dtype: datetime64[ns]

# %%
first_ride_daily_counts
# Out:
#             rider_first_ride_date
# 2015-04-27                    226
# 2019-01-29                     24
# 2019-03-05                     22
# 2016-05-31                     35
# 2015-05-02                    326
# ...                           ...
# 2016-04-15                     24
# 2019-01-28                      6
# 2018-06-28                      1
# 2015-07-08                     18
# 2015-05-01                     80
#
# [147 rows x 1 columns]

# %%
count_series = pd.Series(first_ride_daily_counts.values.tolist())
count_series
flattened_count_series = [value[0] for value in count_series]
count_series = flattened_count_series

# %%
# pd.concat(date_series, count_series)
date_firstrides = pd.DataFrame({"date" : date_series, "number of first rides" : count_series})

# %%
date_firstrides = date_firstrides.sort_values(by = 'date')
date_firstrides = date_firstrides.reset_index(drop=True)
date_firstrides
# Out:
#           date  number of first rides
# 0   2015-04-20                    295
# 1   2015-04-21                    118
# 2   2015-04-22                     12
# 3   2015-04-23                    120
# 4   2015-04-24                     11
# ..         ...                    ...
# 142 2021-07-20                      1
# 143 2021-08-05                      4
# 144 2021-08-26                      1
# 145 2021-09-01                      2
# 146 2021-09-07                      3
#
# [147 rows x 2 columns]

# %%
date_firstrides.plot.line(x = "date", y = "number of first rides")
# Out:
# <AxesSubplot:xlabel='date'>

# %%
services_df['rider_first_ride_date'].value_counts().hist(bins = 100)
# Out:
# <AxesSubplot:>

# %%
services_df['rider_first_ride_date'].value_counts().plot.scatter( x = services_df['rider_first_ride_date'].value_counts().index, y = services_df['rider_first_ride_date'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12948/3716927411.py in <module>
# ----> 1 services_df['rider_first_ride_date'].value_counts().plot.scatter( x = services_df['rider_first_ride_date'].value_counts().index, y = services_df['rider_first_ride_date'].value_counts())
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in scatter(self, x, y, s, c, **kwargs)
#    1634             ...                       colormap='viridis')
#    1635         """
# -> 1636         return self(kind="scatter", x=x, y=y, s=s, c=c, **kwargs)
#    1637
#    1638     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
# --> 919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#     920         elif kind in self._series_kinds:
#     921             if isinstance(data, ABCDataFrame):
#
# ValueError: plot kind scatter can only be used for data frames

# %% [markdown]
# # Largest Donation Amount

# %%
donations_df.head()
# Out:
#    anon_donor_id      zip  status  do_not_mail  do_not_call organisation  \
# 0             92  19003.0  Active        False        False            N
# 1            321  19096.0  Active        False        False            N
# 2            559  19146.0  Active        False        False            N
# 3            926  19041.0  Active        False        False            N
# 4            860  10038.0  Active        False        False            N
#
#          date  amount   form    campaign target
# 0  01/01/2019    40.0  Check     Clients   Gift
# 1  01/02/2019    25.0  Check  Fall Towns   Gift
# 2  01/02/2019   250.0  Check  Fall Towns   Gift
# 3  01/03/2019    50.0  Check  Fall Towns   Gift
# 4  01/04/2019   165.0  Check        Misc   Gift

# %%
max(donations_df.amount)
# Out:
# 186092.0

# %%
donations_df.loc[: , "amount"] == max(donations_df.amount)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2185    False
# 2186    False
# 2187    False
# 2188    False
# 2189    False
# Name: amount, Length: 2190, dtype: bool

# %%
mask = donations_df.loc[: , "amount"] == max(donations_df.amount)

# %%
donations_df[mask]
# Out:
#       anon_donor_id  zip  status  do_not_mail  do_not_call organisation  \
# 1809            589  NaN  Active        False        False            N
#
#             date    amount   form campaign target
# 1809  01/14/2021  186092.0  Check     Misc   Gift

# %% [markdown]
# # Services Provided over Each Time of Day
# Hours will be in military time so 14:00 = 2pm.

# %% [markdown]
# Starting with just the care table, we have the following results:

# %%
care_df.head()
# Out:
#    anon_ID      assistance_date                        assistance_category  \
# 0      531  2019-01-01 12:50:00  Remote Contact with client (phone, email)
# 1      531  2019-01-02 07:30:00  Remote Contact with client (phone, email)
# 2      581  2019-01-02 09:50:00  Remote Contact with client (phone, email)
# 3      337  2019-01-02 10:10:00  Remote Contact with client (phone, email)
# 4      254  2019-01-02 10:15:00  Remote Contact with client (phone, email)
#
#    amount     unit CommType Party InitiatedBy Benefit_1 Assistance_1  \
# 0     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 1     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 2    14.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 3     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 4     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
#
#   Benefit_2 Assistance_2 Benefit_3 Assistance_3
# 0       NaN          NaN       NaN          NaN
# 1       NaN          NaN       NaN          NaN
# 2       NaN          NaN       NaN          NaN
# 3       NaN          NaN       NaN          NaN
# 4       NaN          NaN       NaN          NaN

# %%
care_df.assistance_category.value_counts()
# Out:
# Remote Contact with client (phone, email)    8736
# Remote Contact w/o client                    1948
# Home Visit                                    766
# Community                                     757
# Internal Discussions                          233
# ElderNet Office                                47
# Name: assistance_category, dtype: int64

# %%
care_df.loc[:, "assistance_date"] = pd.to_datetime(care_df.assistance_date)
care_df.loc[:, "assistance_date"]
# Out:
# 0       2019-01-01 12:50:00
# 1       2019-01-02 07:30:00
# 2       2019-01-02 09:50:00
# 3       2019-01-02 10:10:00
# 4       2019-01-02 10:15:00
#                 ...
# 12482   2021-09-13 11:40:00
# 12483   2021-09-15 09:35:00
# 12484   2021-09-15 10:55:00
# 12485   2021-09-15 14:05:00
# 12486   2021-09-15 18:05:00
# Name: assistance_date, Length: 12487, dtype: datetime64[ns]

# %%
care_df.loc[:, "assistance_date"] = care_df.loc[:, "assistance_date"].dt.hour
care_df.loc[:, "assistance_date"]
# Out:
# 0        12
# 1         7
# 2         9
# 3        10
# 4        10
#          ..
# 12482    11
# 12483     9
# 12484    10
# 12485    14
# 12486    18
# Name: assistance_date, Length: 12487, dtype: int64

# %%
care_df.head()
# Out:
#    anon_ID  assistance_date                        assistance_category  \
# 0      531               12  Remote Contact with client (phone, email)
# 1      531                7  Remote Contact with client (phone, email)
# 2      581                9  Remote Contact with client (phone, email)
# 3      337               10  Remote Contact with client (phone, email)
# 4      254               10  Remote Contact with client (phone, email)
#
#    amount     unit CommType Party InitiatedBy Benefit_1 Assistance_1  \
# 0     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 1     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 2    14.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 3     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 4     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
#
#   Benefit_2 Assistance_2 Benefit_3 Assistance_3
# 0       NaN          NaN       NaN          NaN
# 1       NaN          NaN       NaN          NaN
# 2       NaN          NaN       NaN          NaN
# 3       NaN          NaN       NaN          NaN
# 4       NaN          NaN       NaN          NaN

# %%
hours_assistance_cross = pd.crosstab(care_df.assistance_category, care_df.assistance_date, normalize = 'all')
hours_assistance_cross
# Out:
# assistance_date                                 0        1        2        3   \
# assistance_category
# Community                                  0.00000  0.00000  0.00000  0.00000
# ElderNet Office                            0.00000  0.00000  0.00000  0.00000
# Home Visit                                 0.00000  0.00000  0.00000  0.00000
# Internal Discussions                       0.00000  0.00000  0.00000  0.00000
# Remote Contact w/o client                  0.00024  0.00024  0.00016  0.00008
# Remote Contact with client (phone, email)  0.00032  0.00040  0.00048  0.00032
#
# assistance_date                                  4        5        6   \
# assistance_category
# Community                                  0.000000  0.00000  0.00000
# ElderNet Office                            0.000000  0.00000  0.00000
# Home Visit                                 0.000000  0.00000  0.00000
# Internal Discussions                       0.000000  0.00000  0.00000
# Remote Contact w/o client                  0.000000  0.00008  0.00000
# Remote Contact with client (phone, email)  0.000561  0.00000  0.00016
#
# assistance_date                                  7         8         9   ...  \
# assistance_category                                                      ...
# Community                                  0.000000  0.000240  0.001121  ...
# ElderNet Office                            0.000000  0.000000  0.000320  ...
# Home Visit                                 0.000000  0.000000  0.003363  ...
# Internal Discussions                       0.000000  0.000400  0.001201  ...
# Remote Contact w/o client                  0.000320  0.001041  0.017458  ...
# Remote Contact with client (phone, email)  0.001201  0.005045  0.063666  ...
#
# assistance_date                                  14        15        16  \
# assistance_category
# Community                                  0.011772  0.008489  0.002002
# ElderNet Office                            0.000721  0.000320  0.000480
# Home Visit                                 0.009850  0.009129  0.008729
# Internal Discussions                       0.001682  0.002883  0.001281
# Remote Contact w/o client                  0.021142  0.018900  0.011692
# Remote Contact with client (phone, email)  0.104829  0.096821  0.051413
#
# assistance_date                                  17        18        19  \
# assistance_category
# Community                                  0.000000  0.000000  0.000000
# ElderNet Office                            0.000000  0.000000  0.000000
# Home Visit                                 0.000240  0.000000  0.000000
# Internal Discussions                       0.000080  0.000080  0.000080
# Remote Contact w/o client                  0.001682  0.000641  0.000160
# Remote Contact with client (phone, email)  0.004725  0.002002  0.001441
#
# assistance_date                                  20        21        22  \
# assistance_category
# Community                                  0.000000  0.000000  0.000000
# ElderNet Office                            0.000000  0.000000  0.000000
# Home Visit                                 0.000000  0.000080  0.000000
# Internal Discussions                       0.000000  0.000000  0.000000
# Remote Contact w/o client                  0.000320  0.000320  0.000240
# Remote Contact with client (phone, email)  0.001441  0.001602  0.001922
#
# assistance_date                                  23
# assistance_category
# Community                                  0.000160
# ElderNet Office                            0.000000
# Home Visit                                 0.000000
# Internal Discussions                       0.000000
# Remote Contact w/o client                  0.000480
# Remote Contact with client (phone, email)  0.001922
#
# [6 rows x 24 columns]

# %%
sns.heatmap(hours_assistance_cross, cmap = 'mako')
# Out:
# <AxesSubplot:xlabel='assistance_date', ylabel='assistance_category'>

# %% [markdown]
# It appears that most of the assistance given has been remote contact.
# It has been during the hours of 9-5pm and

# %% [markdown]
# ### Now, that we have something that works, concatenating in the pantry data.

# %%
care_and_pantry_df = pd.concat([care_df, pantry_df])
care_and_pantry_df.head()
# Out:
#    anon_ID assistance_date                        assistance_category  amount  \
# 0      531              12  Remote Contact with client (phone, email)     2.0
# 1      531               7  Remote Contact with client (phone, email)     2.0
# 2      581               9  Remote Contact with client (phone, email)    14.0
# 3      337              10  Remote Contact with client (phone, email)     1.0
# 4      254              10  Remote Contact with client (phone, email)     1.0
#
#       unit CommType Party InitiatedBy Benefit_1 Assistance_1 Benefit_2  \
# 0  Minutes      NaN   NaN         NaN       NaN          NaN       NaN
# 1  Minutes      NaN   NaN         NaN       NaN          NaN       NaN
# 2  Minutes      NaN   NaN         NaN       NaN          NaN       NaN
# 3  Minutes      NaN   NaN         NaN       NaN          NaN       NaN
# 4  Minutes      NaN   NaN         NaN       NaN          NaN       NaN
#
#   Assistance_2 Benefit_3 Assistance_3
# 0          NaN       NaN          NaN
# 1          NaN       NaN          NaN
# 2          NaN       NaN          NaN
# 3          NaN       NaN          NaN
# 4          NaN       NaN          NaN

# %% [markdown]
# Unlike before, I will be rounding to the nearest hour using dt.round('H') .

# %%
care_df = pd.read_csv('data/care_management_anonymized.csv')
pantry_df = pd.read_csv('data/pantry_anonymized.csv')
care_and_pantry_df = pd.concat([care_df, pantry_df])

care_and_pantry_df.loc[:, "assistance_date"] = pd.to_datetime(care_and_pantry_df.assistance_date)
care_and_pantry_df.loc[:, "assistance_date"] = care_and_pantry_df.loc[:, "assistance_date"].dt.round('H').dt.hour
care_and_pantry_df.head()
# Out:
#    anon_ID  assistance_date                        assistance_category  \
# 0      531               13  Remote Contact with client (phone, email)
# 1      531                8  Remote Contact with client (phone, email)
# 2      581               10  Remote Contact with client (phone, email)
# 3      337               10  Remote Contact with client (phone, email)
# 4      254               10  Remote Contact with client (phone, email)
#
#    amount     unit CommType Party InitiatedBy Benefit_1 Assistance_1  \
# 0     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 1     2.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 2    14.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 3     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
# 4     1.0  Minutes      NaN   NaN         NaN       NaN          NaN
#
#   Benefit_2 Assistance_2 Benefit_3 Assistance_3
# 0       NaN          NaN       NaN          NaN
# 1       NaN          NaN       NaN          NaN
# 2       NaN          NaN       NaN          NaN
# 3       NaN          NaN       NaN          NaN
# 4       NaN          NaN       NaN          NaN

# %%
care_and_pantry_df.tail()
# Out:
#       anon_ID  assistance_date                assistance_category  amount  \
# 6268      611               14  Food Pantry: Food Pantry Poundage    25.0
# 6269      516               15  Food Pantry: Food Pantry Poundage    25.0
# 6270      274               15  Food Pantry: Food Pantry Poundage    25.0
# 6271      524               15  Food Pantry: Food Pantry Poundage    25.0
# 6272      191               14  Food Pantry: Food Pantry Poundage    25.0
#
#         unit CommType Party InitiatedBy Benefit_1 Assistance_1 Benefit_2  \
# 6268  Pounds      NaN   NaN         NaN       NaN          NaN       NaN
# 6269  Pounds      NaN   NaN         NaN       NaN          NaN       NaN
# 6270  Pounds      NaN   NaN         NaN       NaN          NaN       NaN
# 6271  Pounds      NaN   NaN         NaN       NaN          NaN       NaN
# 6272  Pounds      NaN   NaN         NaN       NaN          NaN       NaN
#
#      Assistance_2 Benefit_3 Assistance_3
# 6268          NaN       NaN          NaN
# 6269          NaN       NaN          NaN
# 6270          NaN       NaN          NaN
# 6271          NaN       NaN          NaN
# 6272          NaN       NaN          NaN

# %%
care_pantry_hours_assistance_cross = pd.crosstab(care_and_pantry_df.assistance_category,
                                                 care_and_pantry_df.assistance_date)
care_pantry_hours_assistance_cross
# Out:
# assistance_date                            0   1   2   3   4   5   6   7   8   \
# assistance_category
# Community                                   0   0   0   0   0   0   0   0   3
# ElderNet Office                             0   0   0   0   0   0   0   0   0
# Food Pantry: Easter Outreach                0   0   0   0   0   0   0   0   0
# Food Pantry: Food Pantry Poundage          27   9   0   0   0   0  15   0  41
# Food Pantry: Holiday Baskets               24  15   6   0   0   0   0   0   0
# Home Visit                                  0   0   0   0   0   0   0   0   0
# Internal Discussions                        0   0   0   0   0   0   0   0   2
# Remote Contact w/o client                   7   2   1   2   1   1   0   3   7
# Remote Contact with client (phone, email)  12   5   7   1   8   2   1   7  31
#
# assistance_date                             9   ...    14    15    16   17  \
# assistance_category                             ...
# Community                                    6  ...   116   114    64    2
# ElderNet Office                              2  ...    10     5     7    0
# Food Pantry: Easter Outreach                 0  ...     0     4     0    0
# Food Pantry: Food Pantry Poundage           33  ...   973   809   250   46
# Food Pantry: Holiday Baskets                 5  ...    26    56    94   19
# Home Visit                                  22  ...   135   111   141   18
# Internal Discussions                         7  ...    30    26    27    6
# Remote Contact w/o client                  105  ...   245   232   235   39
# Remote Contact with client (phone, email)  383  ...  1245  1161  1138  120
#
# assistance_date                            18  19  20  21  22  23
# assistance_category
# Community                                   0   0   0   0   0   2
# ElderNet Office                             0   0   0   0   0   0
# Food Pantry: Easter Outreach                0   0   0   0   0   0
# Food Pantry: Food Pantry Poundage           1  14   0   7  36   0
# Food Pantry: Holiday Baskets                0   0   0   0  31  14
# Home Visit                                  0   0   0   1   0   0
# Internal Discussions                        0   2   0   0   0   0
# Remote Contact w/o client                  14   4   3   5   3   3
# Remote Contact with client (phone, email)  38  14  20  16  25  25
#
# [9 rows x 24 columns]

# %% [markdown]
# ### Busiest times of the day for each service:

# %%
sns.heatmap(care_pantry_hours_assistance_cross, cmap = 'mako')
# Out:
# <AxesSubplot:xlabel='assistance_date', ylabel='assistance_category'>

# %% [markdown]
# This chart shows the relative frequency of different services at different times of the day.
#
# Note that the **food pantry** service has different peaks than the **remote contact with client** service.
#
# ---
#
# **Food pantry** has the most events at 11am.
#
# **Remote contact with client (phone, email)** has the most events at noon and 2pm.
#
# ---
#
# This is a messy comparison, but the data below should be easier to read:

# %% [markdown]
# ### When did events happen overall?

# %%
sns.heatmap(care_and_pantry_df.loc[: , 'assistance_date'].value_counts().sort_index().values.reshape(24,1),
            cmap = "mako",
           yticklabels = range(0, 25))
# Out:
# <AxesSubplot:>

# %% [markdown]
# -----
#
# ### When did specifically food pantry events take place?

# %%
pantry_df = pd.read_csv('data/pantry_anonymized.csv')
pantry_df.loc[:, "assistance_date"] = pd.to_datetime(pantry_df.assistance_date)
pantry_df.loc[:, "assistance_date"] = pantry_df.loc[:, "assistance_date"].dt.round('H').dt.hour
sns.heatmap(pantry_df.loc[: , 'assistance_date'].value_counts().sort_index().values.reshape(24,1),
            cmap = "mako",
           yticklabels = range(0, 25))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12948/178248709.py in <module>
#       2 pantry_df.loc[:, "assistance_date"] = pd.to_datetime(pantry_df.assistance_date)
#       3 pantry_df.loc[:, "assistance_date"] = pantry_df.loc[:, "assistance_date"].dt.round('H').dt.hour
# ----> 4 sns.heatmap(pantry_df.loc[: , 'assistance_date'].value_counts().sort_index().values.reshape(24,1),
#       5             cmap = "mako",
#       6            yticklabels = range(0, 25))
#
# ValueError: cannot reshape array of size 19 into shape (24,1)

# %%
pantry_df.loc[:, "assistance_date"].value_counts().sort_index()
# Out:
# 0       51
# 1       24
# 2        6
# 6       15
# 8       41
# 9       38
# 10    1090
# 11    1385
# 12     810
# 13     433
# 14     999
# 15     869
# 16     344
# 17      65
# 18       1
# 19      14
# 21       7
# 22      67
# 23      14
# Name: assistance_date, dtype: int64

# %%
ass_by_hour = pantry_df.loc[:, "assistance_date"].value_counts().sort_index()
ass_by_hour[3] = 0
ass_by_hour.sort_index()
# Out:
# 0       51
# 1       24
# 2        6
# 3        0
# 6       15
# 8       41
# 9       38
# 10    1090
# 11    1385
# 12     810
# 13     433
# 14     999
# 15     869
# 16     344
# 17      65
# 18       1
# 19      14
# 21       7
# 22      67
# 23      14
# Name: assistance_date, dtype: int64

# %% [markdown]
# -----
#
# ### When did specifically remote contact events (phone, email) happen?

# %%
care_df = pd.read_csv('data/care_management_anonymized.csv')
care_df.loc[:, "assistance_date"] = pd.to_datetime(care_df.assistance_date)
care_df.loc[:, "assistance_date"] = care_df.loc[:, "assistance_date"].dt.round('H').dt.hour
sns.heatmap(care_df.loc[: , 'assistance_date'].value_counts().sort_index().values.reshape(24,1),
            cmap = "mako",
           yticklabels = range(0, 25))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Remote contact events (phone, email) mostly occurred between across 11pm to 5pm.
# The most events took place before or after 1pm.
